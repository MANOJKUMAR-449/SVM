# %% [markdown]
# # SVM Model

# %%
import pandas as pd
import numpy as np


from sklearn import svm
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report


from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import LabelEncoder
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Loading given training dataset

# %%
train_data=pd.read_csv('/content/drive/Othercomputers/My Laptop/Data Science/DS/Assingments/17-SVM/SalaryData_Train(1).csv')
train_data
# Out:
#        age          workclass  ...          native  Salary
# 0       39          State-gov  ...   United-States   <=50K
# 1       50   Self-emp-not-inc  ...   United-States   <=50K
# 2       38            Private  ...   United-States   <=50K
# 3       53            Private  ...   United-States   <=50K
# 4       28            Private  ...            Cuba   <=50K
# ...    ...                ...  ...             ...     ...
# 30156   27            Private  ...   United-States   <=50K
# 30157   40            Private  ...   United-States    >50K
# 30158   58            Private  ...   United-States   <=50K
# 30159   22            Private  ...   United-States   <=50K
# 30160   52       Self-emp-inc  ...   United-States    >50K
#
# [30161 rows x 14 columns]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# <b> DATA PREPROCESSING </b>

# %%
train_data.columns
# Out:
# Index(['age', 'workclass', 'education', 'educationno', 'maritalstatus',
#        'occupation', 'relationship', 'race', 'sex', 'capitalgain',
#        'capitalloss', 'hoursperweek', 'native', 'Salary'],
#       dtype='object')

# %%
labelencoder = LabelEncoder()
train_data.iloc[:, -1] = labelencoder.fit_transform(train_data.iloc[:,-1])
train_data
# Out:
#        age          workclass  ...          native  Salary
# 0       39          State-gov  ...   United-States       0
# 1       50   Self-emp-not-inc  ...   United-States       0
# 2       38            Private  ...   United-States       0
# 3       53            Private  ...   United-States       0
# 4       28            Private  ...            Cuba       0
# ...    ...                ...  ...             ...     ...
# 30156   27            Private  ...   United-States       0
# 30157   40            Private  ...   United-States       1
# 30158   58            Private  ...   United-States       0
# 30159   22            Private  ...   United-States       0
# 30160   52       Self-emp-inc  ...   United-States       1
#
# [30161 rows x 14 columns]

# %%
train_data_x=pd.get_dummies(train_data.iloc[:,:13])
train_data_x
# Out:
#        age  educationno  ...  native_ Vietnam  native_ Yugoslavia
# 0       39           13  ...                0                   0
# 1       50           13  ...                0                   0
# 2       38            9  ...                0                   0
# 3       53            7  ...                0                   0
# 4       28           13  ...                0                   0
# ...    ...          ...  ...              ...                 ...
# 30156   27           12  ...                0                   0
# 30157   40            9  ...                0                   0
# 30158   58            9  ...                0                   0
# 30159   22            9  ...                0                   0
# 30160   52            9  ...                0                   0
#
# [30161 rows x 102 columns]

# %%
# There are more number of people with lessthan 50,000 
sns.countplot(train_data.Salary);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.figure(figsize=(20,8))
sns.countplot(train_data.occupation);
plt.xlabel("Occupations")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 0, 'Occupations')

# %%
plt.figure(figsize=(20,8))
sns.countplot(train_data.race);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
x=train_data_x
y=train_data['Salary']

# %%
# Splitting data into training and testing data set

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.3)

# %%
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((21112, 102), (21112,), (9049, 102), (9049,))

# %% [markdown]
# ## Tuning svm model with different values of parameters 'gmma' , 'c' and kernal='rbf' for best accuracy

# %%
model = SVC(C=1,)
param_grid = [{'kernel':['rbf'],'gamma':[50,5,10,0.5],'C':[0.1] }]
gsv = GridSearchCV(model,param_grid)
gsv.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=None, error_score=nan,
#              estimator=SVC(C=1.0, break_ties=False, cache_size=200,
#                            class_weight=None, coef0=0.0,
#                            decision_function_shape='ovr', degree=3,
#                            gamma='scale', kernel='rbf', max_iter=-1,
#                            probability=False, random_state=None, shrinking=True,
#                            tol=0.001, verbose=False),
#              iid='deprecated', n_jobs=None,
#              param_grid=[{'C': [0.1], 'gamma': [50, 5, 10, 0.5],
#                           'kernel': ['rbf']}],
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)

# %%
# Accoriding to above gridsearch method these are the best parameters

# %%
gsv.best_params_ , gsv.best_score_
# Out:
# ({'C': 0.1, 'gamma': 0.5, 'kernel': 'rbf'}, 0.7494789592039173)

# %%
# Building model with above parameteres

# %%
model_2=SVC(C=0.01,gamma=0.5,kernel='rbf')
model_2.fit(x_train , y_train)
y_pred = model_2.predict(x_test)
acc = accuracy_score(y_test, y_pred) * 100
print("Accuracy =", acc)
# Out:
# Accuracy = 75.52215714443585

# %% [markdown]
# We got accurcy of 75.5% for the model with C=0.01,gamma=0.5 and kernal as rbf

# %% [markdown]
# ## Building model with c=0.01 and gamma as default

# %%
model_final = SVC(C=0.01,kernel='rbf')
model_final.fit(x_train , y_train)
# Out:
# SVC(C=0.01, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
y_pred = model_final.predict(x_test)

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[6813,   21],
#        [1817,  398]])

# %%
acc = accuracy_score(y_test, y_pred) * 100
print("Accuracy =", acc)
# Out:
# Accuracy = 79.68836335506685

# %% [markdown]
# With above parameters we got better accuracy of 79.6% than compared with  previous model.

# %% [markdown]
# ## Applying Prediction using above model for given test data

# %%
data_test=pd.read_csv('/content/SalaryData_Test(1).csv')
data_test
# Out:
#        age      workclass      education  ...  hoursperweek          native  Salary
# 0       25        Private           11th  ...            40   United-States   <=50K
# 1       38        Private        HS-grad  ...            50   United-States   <=50K
# 2       28      Local-gov     Assoc-acdm  ...            40   United-States    >50K
# 3       44        Private   Some-college  ...            40   United-States    >50K
# 4       34        Private           10th  ...            30   United-States   <=50K
# ...    ...            ...            ...  ...           ...             ...     ...
# 15055   33        Private      Bachelors  ...            40   United-States   <=50K
# 15056   39        Private      Bachelors  ...            36   United-States   <=50K
# 15057   38        Private      Bachelors  ...            50   United-States   <=50K
# 15058   44        Private      Bachelors  ...            40   United-States   <=50K
# ...

# %%
labelencoder = LabelEncoder()
data_test.iloc[:, -1] = labelencoder.fit_transform(data_test.iloc[:,-1])
data_test
# Out:
#        age      workclass      education  ...  hoursperweek          native Salary
# 0       25        Private           11th  ...            40   United-States      0
# 1       38        Private        HS-grad  ...            50   United-States      0
# 2       28      Local-gov     Assoc-acdm  ...            40   United-States      1
# 3       44        Private   Some-college  ...            40   United-States      1
# 4       34        Private           10th  ...            30   United-States      0
# ...    ...            ...            ...  ...           ...             ...    ...
# 15055   33        Private      Bachelors  ...            40   United-States      0
# 15056   39        Private      Bachelors  ...            36   United-States      0
# 15057   38        Private      Bachelors  ...            50   United-States      0
# 15058   44        Private      Bachelors  ...            40   United-States      0
# ...

# %%
data_test_x=pd.get_dummies(data_test.iloc[:,:13])
data_test_x
# Out:
#        age  educationno  ...  native_ Vietnam  native_ Yugoslavia
# 0       25            7  ...                0                   0
# 1       38            9  ...                0                   0
# 2       28           12  ...                0                   0
# 3       44           10  ...                0                   0
# 4       34            6  ...                0                   0
# ...    ...          ...  ...              ...                 ...
# 15055   33           13  ...                0                   0
# 15056   39           13  ...                0                   0
# 15057   38           13  ...                0                   0
# 15058   44           13  ...                0                   0
# 15059   35           13  ...                0                   0
#
# [15060 rows x 102 columns]

# %%
X_test=data_test_x
Y_test=data_test['Salary']

# %%
Y_test_pred=model_final.predict(X_test)

# %%
confusion_matrix(Y_test, Y_test_pred)
# Out:
# array([[11319,    41],
#        [ 3017,   683]])

# %%
acc = accuracy_score(Y_test, Y_test_pred) * 100
print("Accuracy =", acc)
# Out:
# Accuracy = 79.6945551128818

# %% [markdown]
# <b> For the given test dataset we got accuracy of 79.7% using SVM model we created </b>
